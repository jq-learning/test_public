# %%
import pandas as pd
from prophet import Prophet

# %%
df = pd.read_csv('./data/example_wp_log_peyton_manning.csv')

# %%
df.head()
# Out:
#            ds         y
# 0  2007/12/10  9.590761
# 1  2007/12/11  8.519590
# 2  2007/12/12  8.183677
# 3  2007/12/13  8.072467
# 4  2007/12/14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# Initial log joint probability = -19.4685
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       7975.82     0.0031675       1022.09      0.3431      0.3431      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       7991.93   0.000838387       218.466           1           1      242
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       7998.13    0.00190015       94.3224           1           1      356
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       8000.92   0.000121219       78.9874      0.3713      0.3713      477
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      462       8002.26   0.000211873       245.653    1.79e-06       0.001      581  LS failed, Hessian reset
#      499       8003.03   0.000726766       181.374           1           1      629
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      580       8003.43   3.08269e-05       101.406   3.165e-07       0.001      779  LS failed, Hessian reset
#      599       8003.55   6.13258e-05       75.1572       0.929       0.929      804
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       8004.17    0.00121964       217.981           1           1      927
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      704       8004.23   0.000157454        183.63   1.157e-06       0.001      994  LS failed, Hessian reset
#      792       8004.68   2.57449e-07       59.2864      0.1844           1     1110
# Optimization terminated normally:
#   Convergence detected: relative change in objective function was below tolerance

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206065    7.460350    8.891563
# 3266 2017-01-16  8.531087    7.845819    9.263805
# 3267 2017-01-17  8.318498    7.591597    9.069589
# 3268 2017-01-18  8.151121    7.440641    8.884464
# 3269 2017-01-19  8.163058    7.449817    8.873907

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3892/3770723988.py in <module>
#       1 from prophet.plot import plot_plotly, plot_components_plotly
#       2
# ----> 3 plot_plotly(m, forecast)
#
# /workspace/.pip-modules/lib/python3.8/site-packages/prophet/plot.py in plot_plotly(m, fcst, uncertainty, plot_cap, trend, changepoints, changepoints_threshold, xlabel, ylabel, figsize)
#     588     data = []
#     589     # Add actual
# --> 590     data.append(go.Scatter(
#     591         name='Actual',
#     592         x=m.history['ds'],
#
# NameError: name 'go' is not defined

# %%
plot_components_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3892/2812262223.py in <module>
# ----> 1 plot_components_plotly(m, forecast)
#
# /workspace/.pip-modules/lib/python3.8/site-packages/prophet/plot.py in plot_components_plotly(m, fcst, uncertainty, plot_cap, figsize)
#     731     # Identify components to plot and get their Plotly props
#     732     components = {}
# --> 733     components['trend'] = get_forecast_component_plotly_props(
#     734         m, fcst, 'trend', uncertainty, plot_cap)
#     735     if m.train_holiday_names is not None and 'holidays' in fcst:
#
# /workspace/.pip-modules/lib/python3.8/site-packages/prophet/plot.py in get_forecast_component_plotly_props(m, fcst, name, uncertainty, plot_cap)
#     868
#     869     traces = []
# --> 870     traces.append(go.Scatter(
#     871         name=name,
#     872         x=fcst['ds'],
#
# NameError: name 'go' is not defined
